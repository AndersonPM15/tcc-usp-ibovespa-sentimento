# %%
# Parameters
base_path = "C:\\Users\\ander\\OneDrive\\TCC_USP"
run_id = "20251110_165252"

# %%
# 1. Setup de caminhos locais
import os
import subprocess
from datetime import datetime
from pathlib import Path

from src.io import paths
from src.config import loader as cfg

DATA_PATHS = paths.get_data_paths()
PROJECT_PATHS = paths.get_project_paths()
BASE_PATH = str(DATA_PATHS["base"])
RAW_PATH = str(DATA_PATHS["data_raw"])
PROC_PATH = str(DATA_PATHS["data_processed"])
INTERIM_PATH = str(DATA_PATHS["data_interim"])
CONFIG = cfg.load_config()

NB_NAME = "01_preprocessing"
STAMP = datetime.now().strftime("%Y%m%d_%H%M%S")

print("BASE_PATH:", BASE_PATH)
print("PROC_PATH:", PROC_PATH)
# Out:
# BASE_PATH: C:\Users\ander\OneDrive\TCC_USP
# PROC_PATH: C:\Users\ander\OneDrive\TCC_USP\data_processed

# %%
# Legacy Colab mount removido; paths definidos no setup.

# %%
# 3. Carregar IBOV
import pandas as pd, os
ibov_file = os.path.join(RAW_PATH, "ibovespa.csv")
assert os.path.exists(ibov_file), f"Arquivo nÃ£o encontrado: {ibov_file}"
df_ibov = pd.read_csv(ibov_file)
df_ibov["data"] = pd.to_datetime(df_ibov["data"])
print("IBOV:", df_ibov.shape)
display(df_ibov.head())
# Out:
# IBOV: (20, 2)
#         data      close
# 0 2024-01-02  130749.73
# 1 2024-01-03  130673.55
# 2 2024-01-04  131624.44
# 3 2024-01-05  133734.42
# 4 2024-01-08  133528.27

# %%
# 4. Carregar NotÃ­cias
news_file = os.path.join(RAW_PATH, "noticias_exemplo.csv")
assert os.path.exists(news_file), f"Arquivo nÃ£o encontrado: {news_file}"
df_news = pd.read_csv(news_file)
df_news["data"] = pd.to_datetime(df_news["data"])
print("NEWS:", df_news.shape)
display(df_news.head())
# Out:
# NEWS: (10, 5)
#         data    fonte    titulo  \
# 0 2024-01-02  exemplo  Titulo 1
# 1 2024-01-03  exemplo  Titulo 2
# 2 2024-01-04  exemplo  Titulo 3
# 3 2024-01-05  exemplo  Titulo 4
# 4 2024-01-08  exemplo  Titulo 5
#
#                                                texto  sentimento
# 0  Ibovespa sobe com otimismo no mercado internac...           1
# 1   Bolsa cai após dados fracos da economia chinesa.           0
# 2  Petróleo em alta puxa ações da Petrobras para ...           1
# 3    Queda do dólar beneficia empresas exportadoras.           1
# 4         Setor bancário recua com aversão ao risco.           0

# %%
# 5. Pré-processamento de texto
import re, nltk
nltk.download("stopwords")
from nltk.corpus import stopwords

stop_pt = set(stopwords.words("portuguese"))
PATTERN = r"[^A-Za-z\u00C0-\u00FF\s]"

def preprocess_text(t):
    t = re.sub(PATTERN, " ", str(t)).lower()
    toks = [w for w in t.split() if w and w not in stop_pt]
    return " ".join(toks)

# Usar a coluna 'texto'
df_news["clean_text"] = df_news["texto"].apply(preprocess_text)

print("✅ Pré-processamento concluído!")
display(df_news[["texto", "clean_text"]].head())
# Out:
# ✅ Pré-processamento concluído!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ander\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                texto  \
# 0  Ibovespa sobe com otimismo no mercado internac...
# 1   Bolsa cai após dados fracos da economia chinesa.
# 2  Petróleo em alta puxa ações da Petrobras para ...
# 3    Queda do dólar beneficia empresas exportadoras.
# 4         Setor bancário recua com aversão ao risco.
#
#                                      clean_text
# 0  ibovespa sobe otimismo mercado internacional
# 1  bolsa cai após dados fracos economia chinesa
# 2       petróleo alta puxa ações petrobras cima
# 3   queda dólar beneficia empresas exportadoras
# 4            setor bancário recua aversão risco

# %%
from pathlib import Path
print("Arquivos em PROC_PATH:")
for path in Path(PROC_PATH).iterdir():
    size_kb = path.stat().st_size / 1024
    print(f" - {path.name} ({size_kb:0.1f} KB)")
# Out:
# Arquivos em PROC_PATH:
#  - bow_daily.parquet (8.5 KB)
#  - car_mean_all.npy (0.2 KB)
#  - car_mean_by_source.npy (0.3 KB)
#  - desktop.ini (0.2 KB)
#  - dicionario_dados_news.csv (0.4 KB)
#  - etl_report_20251018_152153.json (0.5 KB)
#  - ibovespa_clean.csv (0.4 KB)
#  - index_tfidf_daily.csv (0.0 KB)
#  - labels_y_daily.csv (0.3 KB)
#  - latency_by_daypart.csv (0.0 KB)
#  - latency_by_source.csv (0.0 KB)
#  - latency_events.parquet (3.8 KB)
#  - news_clean.csv (153.2 KB)
#  - news_clean.parquet (104.5 KB)
#  - news_dedup.csv (49.7 KB)
#  - news_dedup.parquet (42.7 KB)
#  - news_multisource_clean.csv (16.8 KB)
#  - news_multisource_clean.parquet (14.5 KB)
#  - noticias_clean.csv (1.3 KB)
#  - noticias_real_clean.csv (59.1 KB)
#  - noticias_real_features.csv (59.8 KB)
#  - results_03_tfidf_models.json (0.3 KB)
#  - results_04_embeddings_models.json (0.3 KB)
#  - results_07_tfidf_real.json (0.2 KB)
#  - results_08_embeddings_real.json (0.2 KB)
#  - results_09_lstm_real.json (0.1 KB)
#  - results_16_models_tfidf_baselines.json (0.0 KB)
#  - results_modelo.json (0.2 KB)
#  - tfidf_daily_index.csv (0.2 KB)
#  - tfidf_daily_matrix.npz (4.0 KB)
#  - tfidf_daily_top_terms_sample.csv (0.5 KB)
#  - tfidf_daily_vocab.json (2.1 KB)
#  - X_tfidf_daily.npz (8.7 KB)
